# %%
import sys
import os
sys.path.append(os.getcwd())    
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_csv(r"..\data\favorita_daily.csv")

def preprocess_dataframe(df):
    # Date Columns
    date_columns = ["sale_date"]
    for col in date_columns:
        df[col] = pd.to_datetime(df[col])

preprocess_dataframe(df)

# %%
plt.figure(figsize=(10,4))
sns.set_theme(style="whitegrid", palette="pastel")
sns.lineplot(data = df, x = 'sale_date', y = 'total_sale')

plt.title("Timeline")
plt.legend(['Favorita daily Sales'])
plt.xlabel("Year")
plt.ylabel("kW/h")
plt.show()

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1684 entries, 0 to 1683
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sale_date   1684 non-null   datetime64[ns]
#  1   total_sale  1684 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 26.4 KB
